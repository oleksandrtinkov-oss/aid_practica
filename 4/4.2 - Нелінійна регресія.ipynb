# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline

# %%
N = 100
x = np.linspace(-2, 2, N)
y = x ** 2 - 3
noise = np.random.normal(0, .5, N)
y0 = x**4 - 3* x**2 +x + 5
y = y0 + noise
plt.grid()
plt.scatter(x, y, marker = '.', color = 'r')
plt.plot(x, y0, color='b')

# %%
x = x.reshape(-1, 1)

# %%
degree = 4
model = make_pipeline(PolynomialFeatures(degree), LinearRegression())
model.fit(x, y)
# Out:
# Pipeline(steps=[('polynomialfeatures', PolynomialFeatures(degree=4)),
#                 ('linearregression', LinearRegression())])

# %%
x_fit = np.linspace(-2, 2, 200).reshape(-1, 1)
y_fit = model.predict(x_fit)

# %%
plt.grid()
plt.plot(x, y0, "b", label="Original function")
plt.scatter(x, y, color="g", marker =".", label="Original + noise", alpha=0.6)
plt.plot(x_fit, y_fit, "r", label="Found function")
plt.legend()

# %%
linreg = model.named_steps["linearregression"]

# %%
linreg.coef_
# Out:
# array([ 0.        ,  1.03618887, -2.95173986, -0.03344544,  0.97614446])

# %%
linreg.intercept_
# Out:
# np.float64(5.053142823312506)

# %%
all = np.hstack(([linreg.intercept_], linreg.coef_[1:]))
all
# Out:
# array([ 5.05314282,  1.03618887, -2.95173986, -0.03344544,  0.97614446])
