# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
N = 100
a = 1
b = 3

x = np.random.uniform(0, 5, N)
noise = np.random.normal(0, .5, N)
y = a * x + b + noise

plt.grid()
plt.scatter(x, y, marker = '.', color = 'r')

# %%
X = x.reshape(-1, 1)

# %%
x
# Out:
# array([0.1405594 , 4.02141993, 4.69237347, 0.48525842, 3.83540387,
#        1.70180976, 1.65033387, 0.13597072, 2.32413288, 2.61708115,
#        3.53556167, 4.36715358, 3.18407441, 2.9000722 , 2.05815394,
#        0.97833638, 3.45537972, 1.15965   , 4.46440013, 3.65776892,
#        0.14719257, 0.33522392, 1.99825739, 0.4189989 , 3.48596225,
#        1.65710968, 1.45524369, 2.94064182, 2.31244869, 0.79556637,
#        0.61200332, 4.15458229, 1.0904198 , 3.45844386, 4.26106873,
#        1.07877228, 1.6490893 , 0.10427202, 2.79764303, 2.66527702,
#        0.59186566, 1.8353014 , 3.4047421 , 1.56665075, 4.33377279,
#        1.29371501, 0.58823646, 2.0305762 , 3.34010733, 0.28927851,
#        4.56200689, 2.89848064, 4.9865737 , 3.5469649 , 4.07896122,
#        1.2380476 , 4.62846908, 3.42565993, 0.37128585, 3.69732793,
#        1.77104779, 2.44353364, 2.07921685, 2.65422523, 4.18431587,
#        3.90804831, 2.46208021, 2.86926934, 1.30917422, 1.42084439,
#        1.33566589, 0.38880636, 1.32654115, 4.19318505, 0.3651186 ,
#        1.74816293, 0.98793934, 1.87120731, 0.10764951, 4.44854328,
#        3.84986981, 0.05221908, 1.28753996, 2.70712822, 4.87038135,
#        2.538069  , 3.71351488, 3.68614438, 3.00450084, 4.85599525,
#        0.91605998, 1.30021236, 1.92815114, 4.38773899, 0.73007407,
#        0.60759208, 2.87357042, 4.37901149, 3.77374014, 0.73526671])

# %%
X
# Out:
# array([[0.1405594 ],
#        [4.02141993],
#        [4.69237347],
#        [0.48525842],
#        [3.83540387],
#        [1.70180976],
#        [1.65033387],
#        [0.13597072],
#        [2.32413288],
#        [2.61708115],
#        [3.53556167],
#        [4.36715358],
#        [3.18407441],
#        [2.9000722 ],
#        [2.05815394],
#        [0.97833638],
#        [3.45537972],
#        [1.15965   ],
#        [4.46440013],
#        [3.65776892],
#        [0.14719257],
#        [0.33522392],
#        [1.99825739],
#        [0.4189989 ],
#        [3.48596225],
#        [1.65710968],
#        [1.45524369],
#        [2.94064182],
#        [2.31244869],
#        [0.79556637],
#        [0.61200332],
#        [4.15458229],
#        [1.0904198 ],
#        [3.45844386],
#        [4.26106873],
#        [1.07877228],
#        [1.6490893 ],
#        [0.10427202],
#        [2.79764303],
#        [2.66527702],
#        [0.59186566],
#        [1.8353014 ],
#        [3.4047421 ],
#        [1.56665075],
#        [4.33377279],
#        [1.29371501],
#        [0.58823646],
#        [2.0305762 ],
#        [3.34010733],
#        [0.28927851],
#        [4.56200689],
#        [2.89848064],
#        [4.9865737 ],
#        [3.5469649 ],
#        [4.07896122],
#        [1.2380476 ],
#        [4.62846908],
#        [3.42565993],
#        [0.37128585],
#        [3.69732793],
#        [1.77104779],
#        [2.44353364],
#        [2.07921685],
#        [2.65422523],
#        [4.18431587],
#        [3.90804831],
#        [2.46208021],
#        [2.86926934],
#        [1.30917422],
#        [1.42084439],
#        [1.33566589],
#        [0.38880636],
#        [1.32654115],
#        [4.19318505],
#        [0.3651186 ],
#        [1.74816293],
#        [0.98793934],
#        [1.87120731],
#        [0.10764951],
#        [4.44854328],
#        [3.84986981],
#        [0.05221908],
#        [1.28753996],
#        [2.70712822],
#        [4.87038135],
#        [2.538069  ],
#        [3.71351488],
#        [3.68614438],
#        [3.00450084],
#        [4.85599525],
#        [0.91605998],
#        [1.30021236],
#        [1.92815114],
#        [4.38773899],
#        [0.73007407],
#        [0.60759208],
#        [2.87357042],
#        [4.37901149],
#        [3.77374014],
#        [0.73526671]])

# %%
model = LinearRegression()
model.fit(X, y)
model
# Out:
# LinearRegression()

# %%
a_found = model.coef_[0]
b_found = model.intercept_

# %%
a_found
# Out:
# np.float64(0.9673486913736339)

# %%
b_found
# Out:
# np.float64(3.0937548883759725)
